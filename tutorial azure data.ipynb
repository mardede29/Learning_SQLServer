-- %%
select * from movie_gross where DATEPART(year,release_date) = 2013
-- Out:
-- (11 rows affected)
-- Total execution time: 00:00:00.005
-- ...

-- %%
select * from movie_gross where genre IS NULL
-- Out:
-- (17 rows affected)
-- Total execution time: 00:00:00.112
-- ...

-- %% [markdown]
-- NOT,AND,OR

-- %%
--select * from movie_gross WHERE genre = 'Adventure' or (genre = 'Musical' and mpaa_rating = 'G')
--select * from movie_gross WHERE (genre = 'Adventure' or genre = 'Musical') and mpaa_rating = 'G'
select * from movie_gross where genre in ('Adventure','Musical','Comedy') and mpaa_rating ='G'
-- Out:
-- (51 rows affected)
-- Total execution time: 00:00:00.007
-- ...
