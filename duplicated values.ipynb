-- %% [markdown]
-- duplicate

-- %%
SELECT count(*) cnt,movie_title FROM movie_gross
group by movie_title
having count(*) >1
-- Out:
-- (5 rows affected)
-- Total execution time: 00:00:00.068
-- <table><tr><th>cnt</th><th>movie_title</th></tr><tr><td>2</td><td>101 Dalmatians</td></tr><tr><td>2</td><td>Bad Company</td></tr><tr><td>2</td><td>Cinderella</td></tr><tr><td>2</td><td>Freaky Friday</td></tr><tr><td>3</td><td>The Jungle Book</td></tr></table>

-- %%
select movie_title from movie_gross  group by movie_title having count(*) >1
-- Out:
-- (5 rows affected)
-- Total execution time: 00:00:00.005
-- <table><tr><th>movie_title</th></tr><tr><td>101 Dalmatians</td></tr><tr><td>Bad Company</td></tr><tr><td>Cinderella</td></tr><tr><td>Freaky Friday</td></tr><tr><td>The Jungle Book</td></tr></table>

-- %%
select * from movie_gross where movie_title in (select movie_title from movie_gross  group by movie_title having count(*) >1)
-- Out:
-- (11 rows affected)
-- Total execution time: 00:00:00.017
-- ...

-- %%
with cte AS
(
select movie_title from movie_gross  group by movie_title having count(*) >1
)
select * from movie_gross m INNER JOIN cte c on m.movie_title  = c.movie_title order by m.movie_title
-- Out:
-- (11 rows affected)
-- Total execution time: 00:00:00.042
-- ...
